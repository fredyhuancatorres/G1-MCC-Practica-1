# %% [markdown]
# ### Generacion de listas de numeros aleatorios

# %%
import random
lista100=[]
lista500=[]
lista1k=[]
lista2k=[]
lista3k=[]
lista4k=[]
lista5k=[]
lista6k=[]
lista7k=[]
lista8k=[]
lista9k=[]
lista10k=[]
lista20k=[]
lista30k=[]
lista40k=[]
lista50k=[]
lista60k=[]
lista70k=[]
lista80k=[]
lista90k=[]
lista100k=[]

# %%
for i in range(100):
    NroAleatorio=random.randrange(0,100)
    lista100.append(NroAleatorio)
for i in range(500):
    NroAleatorio=random.randrange(0,500)
    lista500.append(NroAleatorio)
for i in range(1000):
    NroAleatorio=random.randrange(0,1000)
    lista1k.append(NroAleatorio)
for i in range(2000):
    NroAleatorio=random.randrange(0,2000)
    lista2k.append(NroAleatorio)
for i in range(3000):
    NroAleatorio=random.randrange(0,3000)
    lista3k.append(NroAleatorio)
for i in range(4000):
    NroAleatorio=random.randrange(0,4000)
    lista4k.append(NroAleatorio)
for i in range(5000):
    NroAleatorio=random.randrange(0,5000)
    lista5k.append(NroAleatorio)
for i in range(6000):
    NroAleatorio=random.randrange(0,6000)
    lista6k.append(NroAleatorio)
for i in range(7000):
    NroAleatorio=random.randrange(0,7000)
    lista7k.append(NroAleatorio)
for i in range(8000):
    NroAleatorio=random.randrange(0,8000)
    lista8k.append(NroAleatorio)
for i in range(9000):
    NroAleatorio=random.randrange(0,9000)
    lista9k.append(NroAleatorio)
for i in range(10000):
    NroAleatorio=random.randrange(0,10000)
    lista10k.append(NroAleatorio)
for i in range(20000):
    NroAleatorio=random.randrange(0,20000)
    lista20k.append(NroAleatorio)
for i in range(30000):
    NroAleatorio=random.randrange(0,30000)
    lista30k.append(NroAleatorio)
for i in range(40000):
    NroAleatorio=random.randrange(0,40000)
    lista40k.append(NroAleatorio)
for i in range(50000):
    NroAleatorio=random.randrange(0,50000)
    lista50k.append(NroAleatorio)
for i in range(60000):
    NroAleatorio=random.randrange(0,60000)
    lista60k.append(NroAleatorio)
for i in range(70000):
    NroAleatorio=random.randrange(0,70000)
    lista70k.append(NroAleatorio)
for i in range(80000):
    NroAleatorio=random.randrange(0,80000)
    lista80k.append(NroAleatorio)
for i in range(90000):
    NroAleatorio=random.randrange(0,90000)
    lista90k.append(NroAleatorio)
for i in range(100000):
    NroAleatorio=random.randrange(0,100000)
    lista100k.append(NroAleatorio)

# %% [markdown]
# Imprimiendo listas

# %%
list100= open("lista100.txt","w")
list100.write(str(lista100))
list100.close()
list500= open("lista500.txt","w")
list500.write(str(lista500))
list500.close()
list1k= open("lista1k.txt","w")
list1k.write(str(lista1k))
list1k.close()
list2k= open("lista2k.txt","w")
list2k.write(str(lista2k))
list2k.close()
list3k= open("lista3k.txt","w")
list3k.write(str(lista3k))
list3k.close()
list4k= open("lista4k.txt","w")
list4k.write(str(lista4k))
list4k.close()
list5k= open("lista5k.txt","w")
list5k.write(str(lista5k))
list5k.close()
list6k= open("lista6k.txt","w")
list6k.write(str(lista6k))
list6k.close()
list7k= open("lista7k.txt","w")
list7k.write(str(lista7k))
list7k.close()
list8k= open("lista8k.txt","w")
list8k.write(str(lista8k))
list8k.close()
list9k= open("lista9k.txt","w")
list9k.write(str(lista9k))
list9k.close()
list10k= open("lista10k.txt","w")
list10k.write(str(lista10k))
list10k.close()
list20k= open("lista20k.txt","w")
list20k.write(str(lista20k))
list20k.close()
list30k= open("lista30k.txt","w")
list30k.write(str(lista30k))
list30k.close()
list40k= open("lista40k.txt","w")
list40k.write(str(lista40k))
list40k.close()
list50k= open("lista50k.txt","w")
list50k.write(str(lista50k))
list50k.close()
list60k= open("lista60k.txt","w")
list60k.write(str(lista60k))
list60k.close()
list70k= open("lista70k.txt","w")
list70k.write(str(lista70k))
list70k.close()
list80k= open("lista80k.txt","w")
list80k.write(str(lista80k))
list80k.close()
list90k= open("lista90k.txt","w")
list90k.write(str(lista90k))
list90k.close()
list100k= open("lista100k.txt","w")
list100k.write(str(lista100k))
list100k.close()
